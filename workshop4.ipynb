# %% [markdown]
# <a href="https://colab.research.google.com/github/gurungabhinanthan-jpg/mathworkshop/blob/main/workshop4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a scatter graph of 10 random x and y values between 0 and 50. Label the axis to show
# x – Time taken in seconds
# y – Distance reached
# Title “Buzzer Game Results”
# One you have a working program, add the following code to your program;
# colors=["red","green","blue","yellow","pink","orange","purple","brown"
# ,"cyan","magenta"]
# And add to your scatter() call the ‘c=colors’ argument like so;
# plt.scatter(x, y, c=colors)
# What happens?

# %%
import matplotlib.pyplot as plt
import random

# Generate 10 random x and y values between 0 and 50
x = [random.randint(0, 50) for _ in range(10)]
y = [random.randint(0, 50) for _ in range(10)]

# Define colors
colors = ["red", "green", "blue", "yellow", "pink",
          "orange", "purple", "brown", "cyan", "magenta"]

# Create scatter plot
plt.scatter(x, y, c=colors)

# Label axes
plt.xlabel("Time taken in seconds")
plt.ylabel("Distance reached")

# Title
plt.title("Buzzer Game Results")

# Show plot
plt.show()

# %% [markdown]
# Following data shows the change in population of different animals from 2017 to 2022.
# a. Create a pie chart for the population of each year
# b. Can we show all the pie chart on the single pane? Write the code.

# %%
import matplotlib.pyplot as plt

years = [2017, 2018, 2019, 2020, 2021, 2022]
bears = [8, 54, 93, 116, 137, 184]
dolphins = [150, 77, 32, 11, 6, 1]
whales = [80, 54, 100, 76, 93, 72]

for i in range(len(years)):
    data = [bears[i], dolphins[i], whales[i]]
    labels = ["Bears", "Dolphins", "Whales"]

    plt.figure()
    plt.pie(data, labels=labels, autopct='%1.1f%%')
    plt.title(f"Animal Population in {years[i]}")
    plt.show()

# %%
import matplotlib.pyplot as plt

years = [2017, 2018, 2019, 2020, 2021, 2022]
bears = [8, 54, 93, 116, 137, 184]
dolphins = [150, 77, 32, 11, 6, 1]
whales = [80, 54, 100, 76, 93, 72]

fig, axes = plt.subplots(2, 3, figsize=(12, 8))  # 2 rows, 3 columns

for i, ax in enumerate(axes.flat):
    data = [bears[i], dolphins[i], whales[i]]
    labels = ["Bears", "Dolphins", "Whales"]

    ax.pie(data, labels=labels, autopct='%1.1f%%')
    ax.set_title(f"{years[i]}")

plt.suptitle("Animal Population (2017–2022)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Construct a pie chart to visually display the favorite fruits of the students in a class based on the
# given data: Mango - 45; Orange - 30; Plum - 15; Pineapple - 30; Melon – 30

# %%
import matplotlib.pyplot as plt

# Data
fruits = ["Mango", "Orange", "Plum", "Pineapple", "Melon"]
values = [45, 30, 15, 30, 30]

# Create pie chart
plt.pie(values, labels=fruits, autopct='%1.1f%%')

# Title
plt.title("Favorite Fruits of Students")

# Show chart
plt.show()

# %% [markdown]
# task 4

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
plt.bar(colors, values)
plt.xlabel("Car Color")
plt.ylabel("Number Seen")
plt.title("Car Color Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
plt.bar(colors, values, width=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
plt.barh(colors, values)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
bar_colors = ["red", "silver", "blue", "white", "green"]

plt.bar(colors, values, color=bar_colors)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
plt.pie(values, labels=colors, autopct='%1.1f%%')
plt.title("Car Color Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
myexplode = [0.3, 0, 0, 0, 0]

plt.pie(values, labels=colors, autopct='%1.1f%%', explode=myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
myexplode = [0.3, 0, 0, 0, 0]

plt.pie(values, labels=colors, autopct='%1.1f%%', explode=myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt

colors = ["Red", "Silver", "Blue", "White", "Green"]
values = [123, 230, 78, 193, 12]
myexplode = [0.3, 0, 0, 0, 0]

plt.pie(values, labels=colors, autopct='%1.1f%%',
        explode=myexplode, shadow=True)
plt.show()
